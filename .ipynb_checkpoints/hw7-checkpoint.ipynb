# %% [markdown]
# # Homework 7: Pandas and Seaborn(27 pts)

# %% [markdown]
# name: Sina Bonakdar
#
# email: bonakdar@umich.edu
#
# This homework assignment took me 12 hours in total to complete. (Please help us to gauge the difficulty of the assignment.)

# %% [markdown]
# ## Collaboration Disclosure
#
# In the cell below, please list *everyone* with whom you discussed any of the homework problems, excluding only the GSIs and the course instructor.
#
# If you did not discuss the homework with anyone else, write __"I did not discuss this homework with anyone."__
#
# Even if you discuss questions with other, the code you submit must be only yours. All work is checked with the [MOSS plagiarism detector](https://theory.stanford.edu/~aiken/moss/).

# %% [markdown]
# I did not discuss this homework with anyone.

# %% [markdown]
# ---

# %% [markdown]
# ## Submission Instructions
# Your homework solutions should be written entirely in this Jupyter notebook file. Once it contains your solutions, you should submit this notebook through Canvas.
#
#
# Before submitting, please make sure to __Cells->Run All__ executes without errors; errors in your code translate directly to point deductions.
# In general, you don't need to do explicitly raise errors (e.g. with the ```raise``` function) if we don't ask you to in the problem statement.
# However, even in cases where we ask you to check for errors, your submission should not contain any examples of your functions actually raising those errors.
#
# Note that many parts of this homework where you are expected to type in code will have ```NotImplementedError()``` as a placeholder. You need to delete this function and replace it with your own code.
#
# ## Homework tips
#
# 1. **Start early!** If you run into trouble installing things or importing packages, it’s
# best to find those problems well in advance, not the night before your assignment is
# due when we cannot help you!
#
# 2. **Make sure you back up your work!** At a minimum, do your work in a Dropbox
# folder. Better yet, use git, which is well worth your time and effort to learn.
#
# 3. **Be careful to follow directions!** Remember that Python is case sensitive. If
# you are ask you to define a function called my_function and you define a function
# called My_Function, you will not receive full credit. You may want to copy-paste
# the function names below to make sure that the functions in your notebook match.
#
# ## Error checking
#
# You do not need to do error checking (raising errors, etc.) in your code unless we explicitly ask you to so in a problem.
#
#
# ## Nbgrader
#
# We will be using `nbgrader` to grade your jupyter notebook. You will notice some `read-only` cells in the assignment that contain `assert` statements. These are tests that your code must pass for your solution to be correct. If any of the tests fail, you will get an python error and not get points for that question.
#
# **Note:** The tests shown not are not comprehensive; additional tests will be used at grading time. You are encouraged to read the problem carefully and verify your code covers all possible cases.
#
# **Be careful:** If a jupyter notebook cell takes longer than `60s` to run, the autograder will not grade it and you will receive zero credit for that question.

# %% [markdown]
# # Question 1 (18 pts)
# We will look into the NYC flights dataset using Pandas!

# %% [markdown]
# ## Question 1.1 (2 pts)
# Load the dataset from flights.csv file given with this file into a dataframe variable named `df`

# %%
import pandas as pd
df = pd.read_csv('./Data/flights.csv')
# YOUR CODE HERE
df
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       2013      1    1     517.0             515        2.0     830.0
# 1       2013      1    1     533.0             529        4.0     850.0
# 2       2013      1    1     542.0             540        2.0     923.0
# 3       2013      1    1     544.0             545       -1.0    1004.0
# 4       2013      1    1     554.0             600       -6.0     812.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336771  2013      9   30       NaN            1455        NaN       NaN
# 336772  2013      9   30       NaN            2200        NaN       NaN
# 336773  2013      9   30       NaN            1210        NaN       NaN
# 336774  2013      9   30       NaN            1159        NaN       NaN
# 336775  2013      9   30       NaN             840        NaN       NaN
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# ...

# %%
assert df is not None
assert isinstance(df, pd.core.frame.DataFrame)

# %% [markdown]
# ## Question 1.2 (2 pts)
# Get the total count of flights for each month and display the top three months with the highest count.

# %%
monthly_count = ...
# YOUR CODE HERE
d = dict()
for month in df['month'].unique():
    new_df = df[df['month']==month]
    d[month]= new_df.shape[0]

new_df = pd.Series(d)
new_df_sorted = new_df.sort_values(ascending=False)
monthly_count = new_df_sorted[:3]
monthly_count
# Out:
# 7     29425
# 8     29327
# 10    28889
# dtype: int64

# %%
assert all(monthly_count == pd.Series([29425, 29327, 28889], index = [7, 8, 10]))

# %% [markdown]
# ## Question 1.3 (2 pts)
# First get a new dataframe with the three columns of interest 'carrier', 'month' and 'dep_delay'. Then compute the average dep_delay for each carrier and for each month. Rank the departure delays/month and filter the 1st rank carrier for each month (carrier with the lowest dep_delay for the month will get the 1st rank). Show the results in ascending order of the month
#
# Hint: Some of the functions that can help are rank(), unstack(), stack().

# %%
avg_delay = ...
# YOUR CODE HERE
# new_df = df[['carrier','month','dep_delay']]
# avg_delay_df = pd.DataFrame()
# carrier_lst = []
# month_lst = []
# avg_val_lst = []

# for carrier in new_df['carrier'].unique(): 
#     for month in new_df['month'].unique():
#         avg_val = new_df.loc[(new_df['carrier'] == carrier) & (new_df['month'] == month),'dep_delay'].mean()
#         carrier_lst.append(carrier)
#         month_lst.append(month)
#         avg_val_lst.append(avg_val)

# avg_delay_df['carrier'] = carrier_lst
# avg_delay_df['month'] = month_lst
# avg_delay_df['avg_val'] = avg_val_lst
# avg_delay_df
# avg_delay_sorted = avg_delay_df.sort_values(by=['month', 'avg_val'])
# avg_delay_sorted


df_sub = df[['carrier', 'month', 'dep_delay']]
avg_delay = df_sub.groupby(['month','carrier'])['dep_delay'].mean()
ranked = avg_delay.groupby(level=0).rank(method='dense')
avg_delay = avg_delay[ranked == 1].sort_index()

avg_delay
# Out:
# month  carrier
# 1      VX         1.063492
# 2      AS         0.722222
# 3      HA         1.161290
# 4      HA        -2.100000
# 5      HA        -1.451613
# 6      HA         1.466667
# 7      HA        -1.709677
# 8      HA         1.677419
# 9      HA        -5.440000
# 10     HA        -5.095238
# 11     HA        -5.440000
# 12     HA        -3.142857
# Name: dep_delay, dtype: float64

# %%
# Hidden test here

# %% [markdown]
# ## Question 1.4 (2 pts)
# Find the 5 top destinations in this dataset (most number of flights to). Filter only those flights to these top 5 destinations and then show the distribution of carriers on this filtered data.

# %%
top_carrier_count = ...
# YOUR CODE HERE
top_dest = df['dest'].value_counts()[:5].index.values
df_top = df.loc[df['dest'].isin(top_dest), :]
top_carrier_count = df_top['carrier'].value_counts()
top_carrier_count
# Out:
# carrier
# UA    19469
# DL    17707
# B6    13448
# AA    11826
# MQ     4598
# US     4283
# VX     2580
# FL     2337
# 9E     2029
# EV     1925
# WN       59
# OO        1
# Name: count, dtype: int64

# %%
import numpy as np
assert np.all(top_dest == np.array(['ORD', 'ATL', 'LAX', 'BOS', 'MCO']))

# %% [markdown]
# ## Question 1.5 (2 pts)
# Get the total count of cancelled flights in this dataset. We'll say that a cancelled flight has dep_time missing.

# %%
cancelled_flight_count = ...
# YOUR CODE HERE
cancelled_flight_count = sum(df['dep_time'].isna())

# %%
assert cancelled_flight_count == 8255

# %% [markdown]
# ## Question 1.6 (2 pts)
# Count all the destinations that have a letter 'K' anywhere in the name code.

# %%
dest_with_k = ...

# YOUR CODE HERE
dest_with_k = 0
for row in range(df.shape[0]):
    if 'K' in df.loc[row,'dest']:
        dest_with_k +=1

dest_with_k
# Out:
# 4589

# %%
assert dest_with_k == 4589

# %% [markdown]
# ## Question 1.7 (2 pts)
# Create a new column called speed that computes the speed as distance/air_time

# %%
# YOUR CODE HERE
df['speed'] = df['distance'] / df['air_time']

# %%
assert type(df['speed']) == pd.Series 
assert abs(df['speed'][0] - 6.1674) < 1

# %% [markdown]
# ## Question 1.8 (4 pts)
# Segment the dep_time 24 hours into
# * night from 12 midnight to 5 am
# * morning from 5:01 am to 12 noon
# * afternoon from 12.01 noon to 5 pm
# * evening from 5.01 pm to 12 am
#
# And then run a query to find the total flights in each segment and save that value in the given variable.

# %%
parts_of_day_count = ...
# YOUR CODE HERE
df_night = df.loc[(df['dep_time'] >= 0) & (df['dep_time'] <= 500),:]
df_morning = df.loc[(df['dep_time'] >= 501) & (df['dep_time'] <= 1200),:]
df_afternoon = df.loc[(df['dep_time'] >= 1201) & (df['dep_time'] <= 1700),:]
df_evening = df.loc[(df['dep_time'] >= 1701) & (df['dep_time'] <= 2400) ,:]

parts_of_day_count = {'night': df_night.shape[0], 'morning': df_morning.shape[0], 'afternoon': df_afternoon.shape[0], 
                   'evening': df_evening.shape[0]}

# %%
assert parts_of_day_count['morning'] == 129939
assert parts_of_day_count['evening'] == 98362

# %% [markdown]
# # Question 2 (9 pts)
# In this problem, we will do some exploratory data analytics (EDA) by using some of the visualization libraries in Python.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
flights = pd.read_csv("./Data/flights.csv.gz")
airports = pd.read_csv("./Data/airports.csv")
flights.describe()
# Out:
#            year          month            day       dep_time  sched_dep_time  \
# count  336776.0  336776.000000  336776.000000  328521.000000   336776.000000
# mean     2013.0       6.548510      15.710787    1349.109947     1344.254840
# std         0.0       3.414457       8.768607     488.281791      467.335756
# min      2013.0       1.000000       1.000000       1.000000      106.000000
# 25%      2013.0       4.000000       8.000000     907.000000      906.000000
# 50%      2013.0       7.000000      16.000000    1401.000000     1359.000000
# 75%      2013.0      10.000000      23.000000    1744.000000     1729.000000
# max      2013.0      12.000000      31.000000    2400.000000     2359.000000
#
#            dep_delay       arr_time  sched_arr_time      arr_delay  \
# count  328521.000000  328063.000000   336776.000000  327346.000000
# mean       12.639070    1502.054999     1536.380220       6.895377
# std        40.210061     533.264132      497.457142      44.633292
# ...

# %% [markdown]
# ## Question 2.1 (3 pts)
#
# Line charts are ideal to show a trend line. Draw a line chart to show monthly frequency count of flights as a trend line for the year 2013. Be sure to choose the correct data to display on the x-axis and y-axis.

# %%
fig1 = None
# YOUR CODE HERE
flights_2013 = flights[flights['year']==2013]

vals = flights_2013.groupby('month').size()
fig1 = sns.lineplot(x=vals.index,y=vals.values)
fig1.set_title('Monthly breakdown')
fig1.set_xlabel('Months (1-12)')
fig1.set_ylabel('Monthly Frequency')
# Out:
# Text(0, 0.5, 'Monthly Frequency')

# %%
assert fig1.get_title() == 'Monthly breakdown'
assert fig1.get_xlabel() == 'Months (1-12)'
assert fig1.get_ylabel() == 'Monthly Frequency'
assert dict(fig1.lines[0].get_xydata())[6] == 28243

# %% [markdown]
# ## Question 2.2 (3 pts)
# Show the top 5 airports that people flew into using a bar chart.

# %%
fig2 = None
# YOUR CODE HERE
vals = flights['dest'].value_counts()[:5]
fig_2 = sns.barplot(x = vals.index,y=vals.values)
fig_2.set_title('Top 5 airports that people flew into')
fig_2.set_xlabel('Airport codes')
fig_2.set_ylabel('Total arrivals')


fig2 = sns.barplot(x = vals.index,y=vals.values)
fig2.set_title('Top 5 airports that people flew into')
fig2.set_xlabel('Airport codes')
fig2.set_ylabel('Total arrivals')
# Out:
# Text(0, 0.5, 'Total arrivals')

# %%
x_axis = fig_2.get_xaxis()
text1 = x_axis.get_ticklabels()[0]
assert text1.get_text() == 'ORD'
assert fig_2.get_title() == 'Top 5 airports that people flew into'
assert fig_2.get_xlabel() == 'Airport codes'
assert fig_2.get_ylabel() == 'Total arrivals'

# %% [markdown]
# ## Question 2.3 (3 pts)
#
# Segment the flights based on time-slots with the following criteria
# * flights that depart from 00-5:59am as 'red-eye' flights
# * flights that depart from 6am - 11:59am as 'morning'
# * flights that depart from 12noon - 3:59pm as 'afternoon'
# * flights that depart from 4pm - 11:59pm as 'evening'
#
# And using seaborn create a plot as shown below. PS: Feel free to choose your color palette.
#
# ![segmentation.png](data:image/png;base64,...)

# %%
fig_3 = None
# YOUR CODE HERE
red_eye = flights.loc[(flights['dep_time']==2400) | ((flights['dep_time'] >= 0) & (flights['dep_time'] <= 559)),:]
morning = flights.loc[(flights['dep_time'] >= 600) & (flights['dep_time'] <= 1159), :]
afternoon = flights.loc[(flights['dep_time'] >= 1200) & (flights['dep_time'] <= 1559), :]
evening = flights.loc[(flights['dep_time'] >= 1600) & (flights['dep_time'] <= 2359), :]

import matplotlib.pyplot as plt

fig_3, axes = plt.subplots(1, 4, figsize=(12, 4))

airport_lst = red_eye['origin'].value_counts()
airport_lst = airport_lst.sort_index()
sns.barplot(x=airport_lst.index,y=airport_lst.values,palette=['blue','orange','green'], ax = axes[0])
axes[0].set_ylabel('Flight Count')
axes[0].set_xlabel('')
axes[0].set_title('red-eye(00-5:59am)')
axes[0].set_ylim((0,50000))

airport_lst = morning['origin'].value_counts()
airport_lst = airport_lst.sort_index()
sns.barplot(x=airport_lst.index,y=airport_lst.values,palette=['blue','orange','green'], ax = axes[1])
axes[1].set_xlabel('')
axes[1].set_title('morning(6am-11:59am)')
axes[1].set_yticklabels([])
axes[1].set_ylim((0,50000))

airport_lst = afternoon['origin'].value_counts()
airport_lst = airport_lst.sort_index()
sns.barplot(x=airport_lst.index,y=airport_lst.values,palette=['blue','orange','green'], ax = axes[2])
axes[2].set_xlabel('')
axes[2].set_title('afternoon(12noon-3:59pm)')
axes[2].set_yticklabels([])
axes[2].set_ylim((0,50000))

airport_lst = evening['origin'].value_counts()
airport_lst = airport_lst.sort_index()
sns.barplot(x=airport_lst.index,y=airport_lst.values,palette=['blue','orange','green'], ax = axes[3])
axes[3].set_xlabel('')
axes[3].set_title('evening(4pm-11:59pm)')
axes[3].set_yticklabels([])
axes[3].set_ylim((0,50000))
# Out:
# /var/folders/9y/cg7k2_xx2jq1my4l363t9xbh0000gp/T/ipykernel_48954/2110364072.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=airport_lst.index,y=airport_lst.values,palette=['blue','orange','green'], ax = axes[0])
# /var/folders/9y/cg7k2_xx2jq1my4l363t9xbh0000gp/T/ipykernel_48954/2110364072.py:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=airport_lst.index,y=airport_lst.values,palette=['blue','orange','green'], ax = axes[1])
# /var/folders/9y/cg7k2_xx2jq1my4l363t9xbh0000gp/T/ipykernel_48954/2110364072.py:30: FutureWarning:
#
# ...

# %%
assert fig_3.figure.get_axes()[0].get_title() == 'red-eye(00-5:59am)'
assert fig_3.figure.get_axes()[0].get_ylabel() == 'Flight Count'
assert fig_3.figure.get_axes()[1].get_title() == 'morning(6am-11:59am)'
